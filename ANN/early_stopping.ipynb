# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from pylab import rcParams
import matplotlib.pyplot as plt
import warnings
from mlxtend.plotting import plot_decision_regions
from matplotlib.colors import ListedColormap
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_circles
import seaborn as sns

# %%
X, y = make_circles(n_samples=100, noise=0.1, random_state=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=2)

# %%
model = Sequential()

model.add(Dense(256, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=3500, verbose=0)

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
plot_decision_regions(X_test, y_test.ravel(), clf = model, legend=2)
plt.show()
# Out:
# 9600/9600 [==============================] - 12s 1ms/step
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-cecc50891bc2> in <cell line: 1>()
# ----> 1 plot_decision_regions(X_test, y_test.ravel(), clf = model, legend=2)
#       2 plt.show()
#
# /usr/local/lib/python3.9/dist-packages/mlxtend/plotting/decision_regions.py in plot_decision_regions(X, y, clf, feature_index, filler_feature_values, filler_feature_ranges, ax, X_highlight, res, legend, hide_spines, markers, colors, scatter_kwargs, contourf_kwargs, scatter_highlight_kwargs)
#     242                antialiased=True)
#     243
# --> 244     ax.axis(xmin=xx.min(), xmax=xx.max(), y_min=yy.min(), y_max=yy.max())
#     245
#     246     # Scatter training data samples
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/axes/_base.py in axis(self, arg, emit, **kwargs)
#    2125             self.set_ylim(ymin, ymax, emit=emit, auto=yauto)
#    2126         if kwargs:
# -> 2127             raise _api.kwarg_error("axis", kwargs)
#    2128         return (*self.get_xlim(), *self.get_ylim())
#    2129
#
# TypeError: axis() got an unexpected keyword argument 'y_min'

# %% [markdown]
# # Early Stopping

# %%
model = Sequential()

model.add(Dense(256, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
callback = EarlyStopping(
    monitor="val_loss",
    min_delta=0.00001,
    patience=20,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=False
)

# %%
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=3500, callbacks=callback)
# Out:
# Epoch 1/3500
# 3/3 [==============================] - 1s 99ms/step - loss: 0.6930 - accuracy: 0.5000 - val_loss: 0.7098 - val_accuracy: 0.3500
# Epoch 2/3500
# 3/3 [==============================] - 0s 28ms/step - loss: 0.6911 - accuracy: 0.5250 - val_loss: 0.7099 - val_accuracy: 0.3500
# Epoch 3/3500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6895 - accuracy: 0.5125 - val_loss: 0.7104 - val_accuracy: 0.3500
# Epoch 4/3500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6886 - accuracy: 0.5125 - val_loss: 0.7119 - val_accuracy: 0.3500
# Epoch 5/3500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6880 - accuracy: 0.5375 - val_loss: 0.7132 - val_accuracy: 0.3500
# Epoch 6/3500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6873 - accuracy: 0.5250 - val_loss: 0.7156 - val_accuracy: 0.3500
# Epoch 7/3500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6862 - accuracy: 0.5250 - val_loss: 0.7170 - val_accuracy: 0.3500
# Epoch 8/3500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6858 - accuracy: 0.5250 - val_loss: 0.7173 - val_accuracy: 0.3500
# Epoch 9/3500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6850 - accuracy: 0.5375 - val_loss: 0.7179 - val_accuracy: 0.3500
# Epoch 10/3500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6842 - accuracy: 0.5500 - val_loss: 0.7190 - val_accuracy: 0.3500
# Epoch 11/3500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6836 - accuracy: 0.5500 - val_loss: 0.7193 - val_accuracy: 0.3500
# Epoch 12/3500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6830 - accuracy: 0.5500 - val_loss: 0.7204 - val_accuracy: 0.3500
# Epoch 13/3500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6825 - accuracy: 0.5500 - val_loss: 0.7210 - val_accuracy: 0.4000
# Epoch 14/3500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6819 - accuracy: 0.5375 - val_loss: 0.7214 - val_accuracy: 0.4000
# Epoch 15/3500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6815 - accuracy: 0.5375 - val_loss: 0.7215 - val_accuracy: 0.4000
# Epoch 16/3500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6811 - accuracy: 0.5375 - val_loss: 0.7224 - val_accuracy: 0.4000
# Epoch 17/3500
# 3/3 [==============================] - 0s 24ms/step - loss: 0.6804 - accuracy: 0.5375 - val_loss: 0.7228 - val_accuracy: 0.4000
# Epoch 18/3500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6802 - accuracy: 0.5250 - val_loss: 0.7225 - val_accuracy: 0.4500
# Epoch 19/3500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6800 - accuracy: 0.5250 - val_loss: 0.7226 - val_accuracy: 0.4500
# Epoch 20/3500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6791 - accuracy: 0.5250 - val_loss: 0.7223 - val_accuracy: 0.4500
# Epoch 21/3500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6789 - accuracy: 0.5250 - val_loss: 0.7225 - val_accuracy: 0.4000
# Epoch 21: early stopping

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()
